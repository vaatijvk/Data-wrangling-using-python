# %%
import numpy as np
import pandas as pd

# %%
pip install Quandl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 54.2/54.2 kB 216.6 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl

# %%
suns=quandl.get("SIDC/SUNSPOTS_A")
suns.head()
# Out:
# ---------------------------------------------------------------------------
# LimitExceededError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9332\2114384060.py in <module>
# ----> 1 suns=quandl.get("SIDC/SUNSPOTS_A")
#       2 suns.head()
#
# ~\AppData\Roaming\Python\Python39\site-packages\quandl\get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# ~\AppData\Roaming\Python\Python39\site-packages\quandl\model\dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
# ...

# %%
pip install nasdaq-data-link
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl

# Set your API key
quandl.ApiConfig.api_key = 'n--b5UNiDfa6d1yKzr5N'

# Make an API call
data = quandl.get('NASDAQOMX/COMP', start_date='2023-01-01', end_date='2023-06-01')

# Print the data
print(data)
# Out:
# Empty DataFrame
# Columns: [Index Value, High, Low, Total Market Value, Dividend Market Value]
# Index: []

# %%
suns=quandl.get("SIDC/SUNSPOTS_A")
suns.head()
# Out:
#             Yearly Mean Total Sunspot Number  Yearly Mean Standard Deviation  \
# Date
# 1700-12-31                               8.3                             NaN
# 1701-12-31                              18.3                             NaN
# 1702-12-31                              26.7                             NaN
# 1703-12-31                              38.3                             NaN
# 1704-12-31                              60.0                             NaN
#
#             Number of Observations  Definitive/Provisional Indicator
# Date
# 1700-12-31                     NaN                               1.0
# 1701-12-31                     NaN                               1.0
# 1702-12-31                     NaN                               1.0
# 1703-12-31                     NaN                               1.0
# 1704-12-31                     NaN                               1.0

# %%
suns.tail()
# Out:
#             Yearly Mean Total Sunspot Number  Yearly Mean Standard Deviation  \
# Date
# 2016-12-31                              39.8                             3.9
# 2017-12-31                              21.7                             2.5
# 2018-12-31                               7.0                             1.1
# 2019-12-31                               3.6                             0.5
# 2020-12-31                               8.8                             4.1
#
#             Number of Observations  Definitive/Provisional Indicator
# Date
# 2016-12-31                  9940.0                               1.0
# 2017-12-31                 11444.0                               1.0
# 2018-12-31                 12611.0                               1.0
# 2019-12-31                 12884.0                               1.0
# 2020-12-31                 14440.0                               1.0

# %%
#column filtering
suns_filtered=suns[['Yearly Mean Total Sunspot Number','Definitive/Provisional Indicator']]
suns_filtered.head()
# Out:
#             Yearly Mean Total Sunspot Number  Definitive/Provisional Indicator
# Date
# 1700-12-31                               8.3                               1.0
# 1701-12-31                              18.3                               1.0
# 1702-12-31                              26.7                               1.0
# 1703-12-31                              38.3                               1.0
# 1704-12-31                              60.0                               1.0

# %%
#boolean filtering
suns[suns['Yearly Mean Total Sunspot Number']>suns['Yearly Mean Total Sunspot Number'].mean()]
# Out:
#             Yearly Mean Total Sunspot Number  Yearly Mean Standard Deviation  \
# Date
# 1705-12-31                              96.7                             NaN
# 1717-12-31                             105.0                             NaN
# 1718-12-31                             100.0                             NaN
# 1726-12-31                             130.0                             NaN
# 1727-12-31                             203.3                             NaN
# ...                                      ...                             ...
# 2003-12-31                              99.3                             7.1
# 2011-12-31                              80.8                             6.7
# 2012-12-31                              84.5                             6.7
# 2013-12-31                              94.0                             6.9
# 2014-12-31                             113.3                             8.0
#
# ...

# %%
#proof filtering
suns["20020101":"20131231"]
# Out:
#             Yearly Mean Total Sunspot Number  Yearly Mean Standard Deviation  \
# Date
# 2002-12-31                             163.6                             9.8
# 2003-12-31                              99.3                             7.1
# 2004-12-31                              65.3                             5.9
# 2005-12-31                              45.8                             4.7
# 2006-12-31                              24.7                             3.5
# 2007-12-31                              12.6                             2.7
# 2008-12-31                               4.2                             2.5
# 2009-12-31                               4.8                             2.5
# 2010-12-31                              24.9                             3.4
# 2011-12-31                              80.8                             6.7
# 2012-12-31                              84.5                             6.7
# ...

# %%
#describing the dataframe
suns.describe()
# Out:
#        Yearly Mean Total Sunspot Number  Yearly Mean Standard Deviation  \
# count                        321.000000                      203.000000
# mean                          78.517134                        7.892118
# std                           62.091523                        3.866310
# min                            0.000000                        0.500000
# 25%                           24.200000                        4.550000
# 50%                           65.300000                        7.600000
# 75%                          115.200000                       10.350000
# max                          269.300000                       19.100000
#
#        Number of Observations  Definitive/Provisional Indicator
# count              203.000000                             321.0
# mean              1691.857143                               1.0
# std               2913.060813                               0.0
# ...

# %%
#looking for missing values 
import pandas as pd
pd.isnull(suns).sum()
# Out:
# Yearly Mean Total Sunspot Number      0
# Yearly Mean Standard Deviation      118
# Number of Observations              118
# Definitive/Provisional Indicator      0
# dtype: int64

# %%
#dropping missing values
suns.dropna(inplace=True)

# %%
pd.isnull(suns).sum()
# Out:
# Yearly Mean Total Sunspot Number    0
# Yearly Mean Standard Deviation      0
# Number of Observations              0
# Definitive/Provisional Indicator    0
# dtype: int64

# %%
#filling missing values
suns.fillna(0,inplace=True)

# %%
pd.isnull(suns).sum()
# Out:
# Yearly Mean Total Sunspot Number    0
# Yearly Mean Standard Deviation      0
# Number of Observations              0
# Definitive/Provisional Indicator    0
# dtype: int64

# %%
pivot_table = pd.pivot_table(suns, values='Yearly Mean Standard Deviation', index='Date', columns='Yearly Mean Total Sunspot Number', aggfunc='sum')
